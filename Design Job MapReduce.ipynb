# %% [markdown]
# # Design de um Job MapReduce para Gastos Totais por Cliente #

# %% [markdown]
# * Você já parou para pensar quantas vendas são realizadas por dia em grandes empresas como, por exemplo, Amazon ou WalMart? Empresas que faturam bilhões vendendo os mais variados produtos para um grande número de clientes.
#
# * E se você fosse contratado para um projeto em uma dessas empresas e seu primeiro trabalho fosse calcular o total de vendas por cliente? Tarefa aparentemente simples. Sua primeira abordagem talvez fosse buscar o banco de dados transacional com as informações de vendas, cruzar os dados com o cadastro de clientes e obter o valor total gasto por cliente. Mas quantos clientes uma empresa como a Amazon possui?
#
# * E se a solicitação fosse para gerar o total gasto por cliente nos últimos 5 anos, de modo a criar uma campanha personalizada para os clientes que tiveram os maiores gastos ao longo dos anos? Após alguma pesquisa, você poderia obter um dataset no seguinte formato:

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# * Identificamos que todos os registros dos últimos 5 anos geram um dataset com apenas duas colunas, mas 200 milhões de registros.
#
# * Não é um trabalho para um banco de dados relacional. Precisamos de uma ferramenta que possa rapidamente processar os dados e retornar apenas um valor total por cliente.
#
# * Optamos pela criação um job Map Reduce. Com poucas linhas de código e usando linguagem Python..
#
# * Como processar esse job da forma mais rápida possível? Spark/Hadoop é a solução ideal.

# %% [markdown]
# ## SOLUÇÃO ##

# %% [markdown]
# * Instalação do Hadoop e Spark.
#
# * Criação de um código (Python) para fazer a leitura do dataset e então para cada código de cliente, buscar todos os gastos efetuados e efetuar a soma. Ao final, deve ser apresentado o resultado.
#
# * Executar o job via linha de comando usando o Spark-submit.

# %% [markdown]
# **Cézar Augusto Meira Carmo - cezaraugustomeiracarmo@gmail.com**
#
# **Mini Projeto 3 - Engenharia de Dados com Hadoop e Spark - Data Science Academy.**
